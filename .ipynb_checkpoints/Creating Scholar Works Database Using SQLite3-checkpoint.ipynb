# %%
import sqlite3
from urllib.request import urlopen, urlretrieve
from sqlite3 import Error
import os
import pickle

# %%
db_file = r"Xscholar_works.db"
conn = sqlite3.connect(db_file)

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)
 
    return None

# %%
a_connection = create_connection(db_file)

# %%
create_table_stmt = """ CREATE TABLE IF NOT EXISTS publications (
                                        id integer PRIMARY KEY,
                                        title text NOT NULL,
                                        abstract text,
                                        author text
                                        collabs text,
                                        subject text,
                                        year text,
                                        full_text text DEFAULT NULL
                                    ); """

delete_table_sql = """DROP TABLE publications"""

# %%
def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)

# %%
def drop_table(conn,delete_table_sql):
     
    try:    
        c = conn.cursor()
        c.execute(delete_table_sql)
    except Error as e:
        print(e)

# %%
def insert_to_publications(title, abstract, author, collabs, subject, year, full_text):
    
    # so i need to

# %%
create_table(conn, create_table_stmt)

# %%
drop_table(conn, delete_table_sql)

# %%
from selenium import webdriver
import os
import time
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait

# %%
options = Options()
options.add_experimental_option("prefs", {
  "download.default_directory": os.getcwd() + "\Downloads",
  "download.prompt_for_download": False,
  "download.directory_upgrade": True,
  "safebrowsing.enabled": True
})

# %%
def scholar_works_scraper():
#Instatiate the webdriver and set to implicitly wait for page objects to load
    driver = webdriver.Chrome(options=options)
#     driver.implicitly_wait(5) # seconds loading implicitly

    #Set driver to go to start_page and search a given name
    source_page = "http://scholarworks.csun.edu/handle/10211.2/309"    
    driver.get(source_page)
    
    authors_link_objects = driver.find_elements_by_xpath('//*[@id="aspect_discovery_Navigation_list_discovery"]//a')

    authors = []
    pub_count = []
    research_links = []
    view_more_links = []
    
    for obj in authors_link_objects:
        if obj.text == '... View More':
            break
        else:
            split = obj.text.split('(')
            authors.append(split[0].strip())
            pub_count.append(split[1].replace(')',''))
            research_links.append(obj.get_attribute('href'))
            
    for link in research_links:
        driver.get(link)
        if driver.find_elements_by_xpath('//*[@id="aspect_discovery_Navigation_list_discovery"]/ul/li[2]/ul/li[6]/a'):
            view_more_obj = driver.find_element_by_xpath('//*[@id="aspect_discovery_Navigation_list_discovery"]/ul/li[2]/ul/li[6]/a')
            view_more_links.append(view_more_obj.get_attribute('href'))
        else:
            view_more_links.append('No subjects listed')
            
    return authors, pub_count, research_links, view_more_links

# %%
authors, pub_count, research_links, view_more_links = scholar_works_scraper()

# %%
def collect_subj_links(view_more_links):
    
    driver = webdriver.Chrome(options=options)
    driver.get(view_more_links)
    subject_obj = driver.find_elements_by_xpath('//*[@id="aspect_discovery_SearchFacetFilter_table_browse-by-subject-results"]/tbody/tr/td/a')
    subject_titles = []
    subject_links = []

    for obj in subject_obj:
        subject_titles.append(obj.text)
        subject_links.append(obj.get_attribute("href"))

    if driver.find_elements_by_xpath('//a[@class="next-page-link"]'):
        more_results = True
        next_button =  driver.find_element_by_xpath('//a[@class="next-page-link"]')
        webdriver.ActionChains(driver).move_to_element(next_button).click(next_button).perform()
    else:
        more_results = False

    while more_results:
        subject_obj = driver.find_elements_by_xpath('//*[@id="aspect_discovery_SearchFacetFilter_table_browse-by-subject-results"]/tbody/tr/td/a')

        for obj in subject_obj:
            subject_titles.append(obj.text)
            subject_links.append(obj.get_attribute("href"))


        if driver.find_elements_by_xpath('//a[@class="next-page-link"]'):
            #Click the next button and reselect the next button
            if more_results:
                next_button =  driver.find_element_by_xpath('//a[@class="next-page-link"]')
                webdriver.ActionChains(driver).move_to_element(next_button).click(next_button).perform()
            if driver.find_elements_by_xpath('//a[@class="next-page-link"]'):
                next_button =  driver.find_element_by_xpath('//a[@class="next-page-link"]')
            else:
                more_results = False
                
    subj = []
    subj_count = []
    
    for title in subject_titles:
        split = title.split('(')
        subj.append(split[0].strip())
        subj_count.append(split[1].replace(')',''))
        
    subject_titles = subj
    return subject_titles, subj_count, subject_links

# %%
for link in view_more_links:
    subject_titles, subj_count, subject_links = collect_subj_links(link)

# %%
subject_titles, subj_count, subject_links = collect_subj_links(view_more_links[0])

# %%
subject_titles
# Out:
# ['2-dimiensional systems',
#  'A. Perovskite NiCrO',
#  'ab initio',
#  'Ab initio calculations',
#  'ab initio calculations',
#  'Ab Initio Electronic Structure Calculations',
#  'accelerated molecular dynamics',
#  'Actinide',
#  'Al',
#  'Al/graphite battery',
#  'alloys',
#  'aluminum',
#  'Aluminum and silver',
#  'Anionic Conjugated Polyelectrolytes',
#  'antiferromagnetic semiconductor',
#  'atom molecular dynamics',
#  'Atomic',
#  'Atomic displacement',
#  'atomic relaxation',
#  'Atomic structure',
#  'Atomistic model',
#  'Atomistic Simulation',
#  'Atomistic simulation',
#  'Atomistic simulations',
#  'Band gap',
#  'band structure',
#  'Bande conduction',
#  'Brillouin zone sampling',
#  'bulk diffusion barrier',
#  'C. Structural property',
#  'C60 Molecules',
#  'carbon dioxide',
#  'carbon monoxide',
#  'Carbon nanotubes',
#  'carbon nanotubes',
#  'catalysts',
#  'Cationic Conjugated Polyelectrolytes',
#  'Cauchy-Born hypothesis',
#  'Charge separation',
#  'Charge transfer',
#  'charge-transfer',
#  'charge-transfer plasmon',
#  'Chemical tunining',
#  'chemistry',
#  'chemistry effect',
#  'classical atomistic',
#  'Co/C60/Co/Ni',
#  'CO2',
#  'Computational methodology',
#  'condensed matter',
#  'Conduction band',
#  'conjugated polyelectrolytes',
#  'Continuum',
#  'continuum elasticity theory',
#  'continuum theory of linear elasticity',
#  'Controlling nanoparticle',
#  'controlling nanoparticle',
#  'Copper',
#  'copper',
#  'core structural transition',
#  'core/shell nanoparticle',
#  'core/shell nanoparticles',
#  'Cross slip',
#  'cross-slip',
#  'cross-slip energy barrier',
#  'crystalline aluminum',
#  'crystalline ratios',
#  'crystalline solids',
#  'Cu/HfO2',
#  'curved dislocations',
#  'D. Electronic structure',
#  'defects',
#  'Density functional theory',
#  'density functional theory',
#  'density-functional calculations',
#  'density-functional theory',
#  'density-functional-theory-based quantum simulation',
#  'Density-gradient-corrected embedded atom method',
#  'diffusion',
#  'diketopyrrolopyrrole derivatives',
#  'discrete variation method',
#  'discrete variational method',
#  'discrete variational X? method',
#  'Dislocation',
#  'dislocation',
#  'dislocation constriction energy',
#  'Dislocation core',
#  'dislocation core',
#  'Dislocation core properties',
#  'Dislocation cores',
#  'dislocation for length scales',
#  'Dislocation glide',
#  'Dislocation motion',
#  'Dislocation structure',
#  'Dislocations',
#  'dislocations',
#  'Dissimilar materials',
#  'DNA Sequencing',
#  'Dynamic method',
#  'E. High pressure',
#  'elastic field',
#  'Elastic properties',
#  'elastic strain',
#  'electrocatalysis',
#  'electrochemical cycling',
#  'Electrochemical reduction',
#  'electrochemical reduction',
#  'electrochemistry',
#  'electrodes',
#  'electromagnetism',
#  'electron density of states',
#  'Electron transfer',
#  'electronic distribution',
#  'Electronic structure',
#  'electronic structure',
#  'embedded atom method',
#  'embedded atom potential',
#  'embedded-atom method',
#  'energetic disorder',
#  'environmental embrittlement',
#  'exciton',
#  'Exciton diffusion',
#  'exciton diffusion length',
#  'external quantum efficiency',
#  'f H embrittlement',
#  'face-centered tetragonal structure',
#  'Faradaic efficiency',
#  'Fe',
#  'FePd',
#  'ferritic steels',
#  'First principles',
#  'First-Principles',
#  'first-principles',
#  'First-principles calculations',
#  'First-Principles Electron Structure Theory',
#  'First-principles electron structure theory',
#  'Fonction onde',
#  'formates',
#  'Fracture mechanics',
#  'fracture mechanics',
#  'Fullerenes',
#  'generalized coordination number',
#  'generalized stacking fault energy surface',
#  'gradient corrections',
#  'graphene fluoride',
#  'graphite intercalation compounds',
#  'Hardening',
#  'He bubble nucleation',
#  'helium',
#  'Helmholtz free binding energy',
#  'Heterojunction',
#  'Heyrovsky reaction',
#  'hopping transport',
#  'hybrid exchange-correlation functionals',
#  'hybrid halide perovskites',
#  'Hybrid material',
#  'Hybrid model',
#  'hybrid organic/inorganic',
#  'Hydrogen',
#  'hydrogen',
#  'Hydrogen adsorption',
#  'hydrogen embrittlement',
#  'Hydrogen Evolution Reaction',
#  'hydrogen generation',
#  'hydrogen impurities',
#  'hydrogen-induced vacancy superabundant formation',
#  'hyperfine fields',
#  'hysteresis',
#  'impurity',
#  'impurity solution energy',
#  'inorganic framework',
#  'inorganic nanoparticles',
#  'interaction energy',
#  'Interface',
#  'intermolecular transition density',
#  'internal quantum efficiency',
#  'interplanar relaxation',
#  'iterative diagonalization',
#  'Kohn-Sham',
#  'large scale simulations',
#  'large-scale calculations',
#  'Lattice parameters',
#  'linearized augmented plane wave',
#  'linearized-augmented plane-wave method',
#  'liquid fuel oxidation reaction',
#  'local density approximation',
#  'localized surface plasmon resonances',
#  'LSPR',
#  'magnetic interaction',
#  'magnetic tunnel junction',
#  'Material physics',
#  'material physics',
#  'Material science',
#  'material science',
#  'materials physics',
#  'materials science',
#  'mechanical coupling',
#  'metallic bonding',
#  'metallic nanoparticles',
#  'metallic nanostructure',
#  'Misfit dislocation',
#  'Mn ductilization',
#  'Mobility edges',
#  'Molecular',
#  'molecular dynamics',
#  'Molecular dynamics calculations',
#  'Molecular dynamics simulations',
#  'molecular mechanical coupling method',
#  'molecular mechanics',
#  'molecular mechanics method',
#  'Molecular orbital',
#  'molecular-mechanics',
#  'Monolayer',
#  'Monte Carlo simulations',
#  'multimetallic platinum alloy nanowires',
#  'multiscale computational framework',
#  'multiscale modeling',
#  'multiscale quantum-mechanics',
#  'multiscale quasicontinuum',
#  'multiscale simulation',
#  'nanoindentation',
#  'nanoparticle catalyst',
#  'nanoparticles',
#  'near-surface-alloys',
#  'Ni3Al',
#  'NiAu alloy nanoparticles',
#  'Nickel',
#  'nine-vacancy cluster',
#  'nolem emtal',
#  'non-platinum electrocatalysts',
#  'nonsingular elastic fields',
#  'Numerical simulation',
#  'numerical simulations',
#  'OFDFT',
#  'orbital-free density functional theory',
#  'orbital-free density-functional theory',
#  'organic compounds',
#  'organic photovoltaics',
#  'organic semiconductors',
#  'Organic-inorganic hybrid materials',
#  'organohalide perovskite based solar cells',
#  'Organometal halide perovskite solar cells',
#  'Oxygen',
#  'oxygen embrittlement',
#  'oxygen reduction',
#  'oxygen reduction reaction',
#  'oxygen-reduction reaction',
#  'parametric dislocation dynamics',
#  'Parametric method',
#  'Partial dislocation',
#  'Peierls method',
#  'Peierls stress',
#  'Peierls-Nabarro',
#  'peierls-nabarro',
#  'Peierls-Nabarro model',
#  'perovskite oxide',
#  'Phonon-assisted hole transition rates',
#  'photoexcited electrons',
#  'photoexcited interfacial electron transfer',
#  'Photovoltaic cell',
#  'plasmonic',
#  'Plasmonic resonance',
#  'plasmonic resonance',
#  'Plasmonics',
#  'plasmonics',
#  'Plastic Deformation',
#  'Plastic deformation',
#  'plastic deformation',
#  'Platinum',
#  'platinum-lead/platinum core nanoplate',
#  'polymer/fullerene heterojunctions',
#  'Polymers',
#  'potassium bicarbonate',
#  'pseudopotential construction',
#  'QCDFT',
#  'QED',
#  'quantum coupling',
#  'Quantum electrodynamics',
#  'quantum electrodynamics',
#  'quantum mechanical coupling method',
#  'quantum mechanical simulations',
#  'quantum mechanics',
#  'quantum mechanics-molecular mechanics',
#  'Quantum yield',
#  'quantum-level accuracy',
#  'quantum-mechanical treatment',
#  'Quantum-mechanics/molecular-mechanics method',
#  'quantum/molecular mechanics',
#  'quasicontinuum',
#  'reversible hydrogen electrode',
#  'scanning tunneling microscopy',
#  'segregation-induced embrittlement',
#  'semi-discrete variational Peierls-Nabarro',
#  'semidiscrete',
#  'semidiscrete variational Peierls-Nabarro model',
#  'Shockley partials',
#  'simple metallic systems',
#  'simulations',
#  'single-molecule junction',
#  'size dependence',
#  'small molecules',
#  'Solar cell',
#  'solar cells',
#  'sole energetics formulation',
#  'spectroscopy',
#  'Stacking fault',
#  'Stacking fault energies',
#  'straight dislocation',
#  'Strengthening',
#  'Stress effects',
#  'sulfur-induced amorphization',
#  'supersaturation',
#  'surface atoms',
#  'Surface energy',
#  'Surface engineering',
#  'Surface states',
#  'Tafel reaction',
#  'tantalum and tantalum nitrides',
#  'TD-OFDFT',
#  'temperature dependent model generalized pseudopotential theory',
#  'Tera-to-Petascale simulations',
#  'thermodynamic process|material science',
#  'thermodynamic stability',
#  'thermodynamics',
#  'thermodynamics analysis',
#  'Thin film',
#  'Thiophene derivative polymer',
#  'time-dependent density functional theory',
#  'time-dependent density functional theory calculations',
#  'time-dependent orbital-free density functional theory',
#  'Tin',
#  'tin',
#  'tin dioxide',
#  'Titanium aluminide',
#  'Transfert charge',
#  'Transient absorption measurements',
#  'transition path',
#  'tunnel magnetoresistance',
#  'vacancy clusterization',
#  'vacancy lubrication effect']

# %%
subject_links[4]
# Out:
# 'http://scholarworks.csun.edu/handle/10211.2/309/discover?field=subject&filtertype_0=author&filter_0=Lu%2C+Gang&filter_relational_operator_0=equals&filtertype=subject&filter_relational_operator=equals&filter=ab+initio+calculations'

# %%
def articles_collector(subject_links):
    driver = webdriver.Chrome(options=options)
    driver.get(subject_links)
    art_objs = driver.find_elements_by_xpath('//*[@id="aspect_discovery_SimpleSearch_div_search-results"]/ul/ul/li/div[2]/div/a')
    art_links = []
    art_titles = []
    for obj in art_objs:
        art_links.append(obj.get_attribute('href'))
        art_titles.append(obj.text)
        
    return art_links, art_titles

# %%
art_links, art_titles = articles_collector(subject_links[2])

# %%
art_titles
# Out:
# ['Monte Carlo Simulations of Grain Boundary Sliding and Migration: Effect of Temperature and Vacancy',
#  'Multiplane-induced widening of stacking faults in fcc metals',
#  'Non-singular descriptions of dislocation cores: a hybrid ab initio continuum approach']

# %%
art_links[1]
# Out:
# 'http://scholarworks.csun.edu/handle/10211.3/196549'

# %%
from io import StringIO 
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter, PDFResourceManager 
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage

# %%
class PdfConverter:
    def __init__(self, file_path):
        self.file_path = file_path
    
    # convert pdf file to a string which has space among words 
    def convert_pdf_to_txt(self):
        rsrcmgr = PDFResourceManager()
        retstr = StringIO()
        codec = 'utf-8'  # 'utf16','utf-8'
        laparams = LAParams()
        device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
        fp = open(self.file_path, 'rb')
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        password = ""
        maxpages = 0
        caching = True
        pagenos = set()
        for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password, caching=caching, check_extractable=True):
            interpreter.process_page(page)
        fp.close()
        device.close()
        str = retstr.getvalue()
        retstr.close()
        return str
    # convert pdf file text to string and save as a text_pdf.txt file
    def save_convert_pdf_to_txt(self):
        content = self.convert_pdf_to_txt()
        txt_pdf = open('text_pdf.txt', 'wb')
        txt_pdf.write(content.encode('utf-8'))
        txt_pdf.close()

# %%
def citation_collector(art_links):
    
    driver = webdriver.Chrome(options=options)
    driver.get(art_links)
    
    # get the collaborators
    collabs_obj = driver.find_element_by_xpath('//*[@id="aspect_artifactbrowser_ItemViewer_div_item-view"]/div[1]/div[1]')
    collabs = collabs_obj.text
    
    # get the date
    date_obj = driver.find_element_by_xpath('//*[@id="aspect_artifactbrowser_ItemViewer_div_item-view"]/div[1]/div[3]/span[2]')
    date = date_obj.text
    
    # get the abstract
    abstract_obj = driver.find_element_by_xpath('//*[@id="aspect_artifactbrowser_ItemViewer_div_item-view"]/div[1]/div[4]/div')
    abstract = abstract_obj.text
    
    # try to download the pdf
    if driver.find_elements_by_xpath('//*[@id="aspect_artifactbrowser_ItemViewer_div_item-view"]/div[2]/div/div[3]/ul/li/a'):
        # get the pdf link object
        pdf_link_obj = driver.find_element_by_xpath('//*[@id="aspect_artifactbrowser_ItemViewer_div_item-view"]/div[2]/div/div[3]/ul/li/a')
        # get the link
        pdf_link = pdf_link_obj.get_attribute('href')
        # download the pdf
        urlretrieve(pdf_link, 'a.pdf')
        
        pdf_text = PdfConverter('a.pdf').convert_pdf_to_txt()
        
        # delete the pdf
        os.remove('a.pdf')
    else:
        pdf_text = ""
        
        
    return collabs, date, abstract, pdf_text

# %%
collabs, date, abstract, pdf_text = citation_collector(art_links[1])
collabs
# Out:
# 'Shehadeh, Mutasem; Lu, Gang; Chen, Z.; Kioussis, Nicholas'

# %%
collabs, date, abstract, pdf_text = citation_collector('http://scholarworks.csun.edu/handle/10211.3/196531')
pdf_text
# Out:
# 'VOLUME 87, NUMBER 9\n\nP H Y S I C A L R E V I E W L E T T E R S\n\n27 AUGUST 2001\n\nHydrogen-Enhanced Local Plasticity in Aluminum: An Ab Initio Study\n\nGang Lu,1,2,* Qing Zhang,1 Nicholas Kioussis,1 and Efthimios Kaxiras2\n\n1Department of Physics, California State University Northridge, Northridge, California 91330\n\n2Department of Physics, Harvard University, Cambridge, Massachusetts 02138\n\n(Received 13 April 2001; published 8 August 2001)\n\nDislocation core properties of Al with and without H impurities are studied using the Peierls-Nabarro\nmodel with parameters determined by ab initio calculations. We ﬁnd that H not only facilitates dislocation\nemission from the crack tip but also enhances dislocation mobility dramatically, leading to macroscopi-\ncally softening and thinning of the material ahead of the crack tip. We observe strong binding between\nH and dislocation cores, with the binding energy depending on dislocation character. This dependence\ncan directly affect the mechanical properties of Al by inhibiting dislocation cross-slip and developing\nslip planarity.\n\nDOI: 10.1103/PhysRevLett.87.095501\n\nPACS numbers: 62.20.Fe, 62.20.Mk\n\nThe mechanical properties of solids are not only a func-\ntion of their intrinsic atomic structure, but also of the en-\nvironment in which they exist. Small amounts of impurity\natoms in the environment can drastically change the\nresponse of a solid to external loading. Hydrogen em-\nbrittlement is one of the most important and well-studied\nprocesses of environmental degradation of materials. After\nover a century of studies, the deﬁnitive mechanism of H\nembrittlement still remains unknown although signiﬁcant\nprogress has been made toward developing a detailed\nunderstanding of the problem. Three general mechanisms\nfor H embrittement have been proposed:\n(1) formation\nof a hydride phase; (2) H-enhanced local plasticity; and\n(3) H-induced grain boundary weakening [1]. The under-\nlying atomic processes and the relative importance of the\nthree mechanisms, however, remain uncertain and contro-\nversial. In this paper, we study a key aspect of H embrittle-\nment, referred to as H-enhanced local plasticity (HELP)\n[2], which has attracted much attention recently. There\nseems to be overwhelming evidence that plasticity is a\nfundamental contributor to H embrittlement of virtually all\nsusceptible metals and alloys, including Al, the model ma-\nterial we consider in this paper [1,3,4]. The most dramatic\nexperimental observation is that H increases dislocation\nmobility signiﬁcantly under constant stress.\nThis H-\nenhanced mobility is observed for screw, edge, and\nmixed dislocations as well as for isolated dislocations and\ndislocation tangles [1,5]. Other important experimental\nresults include the observations of slip planarity [4,6] and\nstrong binding between H and dislocation cores [1].\n\nIn contrast to the vast body of experimental evidence,\ntheoretical studies of the HELP mechanism are scarce. To\nour knowledge, the only theoretical investigation of the\nHELP mechanism is based on ﬁnite-element modeling of\nelastic interactions among dislocations in the presence of\nH [7]. Although this approach was able to explain the\nH-enhanced dislocation mobility through the H-induced\n“elastic shield” effect, it completely ignores the effects of\nH on dislocation core structure and contains no information\nfor the relevant atomic processes, which are critical for a\n\ncomplete understanding of the phenomenon. The purpose\nof our work is to provide a comprehensive understand-\ning of the aforementioned experimental results based on\nan ab initio theoretical framework, which hopefully can\nset the stage for an atomistic theory of H embrittlement.\n\nIn this paper, we have used the recently developed\nsemidiscrete variational Peierls-Nabarro (SVPN) model\n[8–10] with ab initio determined g surfaces [11] and\nelastic constants. This approach has been shown to predict\nrelia ...
